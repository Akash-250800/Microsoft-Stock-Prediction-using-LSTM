# %%
import pandas as pd

df= pd.read_csv('MSFT.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.061434
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.063628
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.064725
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.063079
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061982
# ...          ...         ...         ...         ...         ...         ...
# 9078  2022-03-18  295.369995  301.000000  292.730011  300.429993  300.429993
# 9079  2022-03-21  298.890015  300.140015  294.899994  299.160004  299.160004
# 9080  2022-03-22  299.799988  305.000000  298.769989  304.059998  304.059998
# 9081  2022-03-23  300.510010  303.230011  297.720001  299.489990  299.489990
# 9082  2022-03-24  299.140015  304.200012  298.320007  304.100006  304.100006
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9078    43317000
# 9079    28351200
# 9080    27599700
# 9081    25715400
# 9082    24446900
#
# [9083 rows x 7 columns]

# %%
df = df[['Date','Close']]
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9078  2022-03-18  300.429993
# 9079  2022-03-21  299.160004
# 9080  2022-03-22  304.059998
# 9081  2022-03-23  299.489990
# 9082  2022-03-24  304.100006
#
# [9083 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9078    2022-03-18
# 9079    2022-03-21
# 9080    2022-03-22
# 9081    2022-03-23
# 9082    2022-03-24
# Name: Date, Length: 9083, dtype: object

# %%
import datetime

def str_to_datetime(s):
    split = s.split('-')
    year, month, day = int(split[0]), int(split[1]), int(split[2])
    return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9078  2022-03-18  300.429993
# 9079  2022-03-21  299.160004
# 9080  2022-03-22  304.059998
# 9081  2022-03-23  299.489990
# 9082  2022-03-24  304.100006
#
# [9083 rows x 2 columns]

# %%
df['Date'] =df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_9996\2409041544.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] =df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9078   2022-03-18
# 9079   2022-03-21
# 9080   2022-03-22
# 9081   2022-03-23
# 9082   2022-03-24
# Name: Date, Length: 9083, dtype: datetime64[ns]

# %%
df.index= df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2022-03-18  300.429993
# 2022-03-21  299.160004
# 2022-03-22  304.059998
# 2022-03-23  299.489990
# 2022-03-24  304.100006
#
# [9083 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np
def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '2021-03-25', 
                                '2022-03-23', 
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 84544.7578 - mean_absolute_error: 289.0593 - val_loss: 91923.7422 - val_mean_absolute_error: 303.1019
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 84390.0703 - mean_absolute_error: 288.6844 - val_loss: 91577.6562 - val_mean_absolute_error: 302.5305
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 84427.4844 - mean_absolute_error: 288.7933 - val_loss: 91204.4531 - val_mean_absolute_error: 301.9130
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 82742.2500 - mean_absolute_error: 285.8771 - val_loss: 90715.0469 - val_mean_absolute_error: 301.1015
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 82975.1406 - mean_absolute_error: 286.2699 - val_loss: 90167.0234 - val_mean_absolute_error: 300.1900
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 81948.2500 - mean_absolute_error: 284.4265 - val_loss: 89424.8828 - val_mean_absolute_error: 298.9513
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 80869.6250 - mean_absolute_error: 282.6321 - val_loss: 88249.2969 - val_mean_absolute_error: 296.9785
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 80577.9141 - mean_absolute_error: 282.1349 - val_loss: 86581.5391 - val_mean_absolute_error: 294.1573
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 79159.8906 - mean_absolute_error: 279.6393 - val_loss: 84692.9609 - val_mean_absolute_error: 290.9295
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 76719.1328 - mean_absolute_error: 275.1097 - val_loss: 82409.6094 - val_mean_absolute_error: 286.9783
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 74414.0234 - mean_absolute_error: 270.8844 - val_loss: 79530.0781 - val_mean_absolute_error: 281.9169
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 72797.3125 - mean_absolute_error: 267.9465 - val_loss: 76494.7734 - val_mean_absolute_error: 276.4811
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 69889.8594 - mean_absolute_error: 262.4604 - val_loss: 73012.9375 - val_mean_absolute_error: 270.1110
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 64426.8281 - mean_absolute_error: 251.9710 - val_loss: 68797.2266 - val_mean_absolute_error: 262.1913
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 60659.7812 - mean_absolute_error: 244.2240 - val_loss: 64389.5664 - val_mean_absolute_error: 253.6466
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 56971.2344 - mean_absolute_error: 236.5352 - val_loss: 59526.8633 - val_mean_absolute_error: 243.8725
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 52853.6367 - mean_absolute_error: 227.5806 - val_loss: 54153.0781 - val_mean_absolute_error: 232.5940
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 47181.4336 - mean_absolute_error: 214.7274 - val_loss: 48104.3750 - val_mean_absolute_error: 219.2056
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 41666.2109 - mean_absolute_error: 201.5907 - val_loss: 41676.2461 - val_mean_absolute_error: 204.0179
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 35277.1250 - mean_absolute_error: 185.0993 - val_loss: 35707.9453 - val_mean_absolute_error: 188.8251
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 29012.3652 - mean_absolute_error: 167.4662 - val_loss: 29686.8301 - val_mean_absolute_error: 172.1449
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 24503.0723 - mean_absolute_error: 153.1834 - val_loss: 24113.9297 - val_mean_absolute_error: 155.1157
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 19712.6738 - mean_absolute_error: 136.3885 - val_loss: 18766.8105 - val_mean_absolute_error: 136.7982
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 14970.5977 - mean_absolute_error: 118.0454 - val_loss: 13731.6016 - val_mean_absolute_error: 116.9554
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10733.4609 - mean_absolute_error: 98.2722 - val_loss: 9445.9053 - val_mean_absolute_error: 96.9165
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6873.8984 - mean_absolute_error: 76.7021 - val_loss: 6191.1777 - val_mean_absolute_error: 78.3468
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4626.0034 - mean_absolute_error: 60.2376 - val_loss: 3832.1147 - val_mean_absolute_error: 61.4748
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3081.3345 - mean_absolute_error: 45.5161 - val_loss: 2241.5718 - val_mean_absolute_error: 46.7825
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1862.8364 - mean_absolute_error: 35.1219 - val_loss: 1275.4502 - val_mean_absolute_error: 34.9640
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1412.5341 - mean_absolute_error: 31.2086 - val_loss: 720.5251 - val_mean_absolute_error: 25.8372
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1070.7676 - mean_absolute_error: 27.9752 - val_loss: 432.9873 - val_mean_absolute_error: 19.4942
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 997.6832 - mean_absolute_error: 26.7485 - val_loss: 286.4560 - val_mean_absolute_error: 15.3158
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1052.6156 - mean_absolute_error: 27.4641 - val_loss: 213.4859 - val_mean_absolute_error: 12.9139
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 959.1544 - mean_absolute_error: 25.9491 - val_loss: 203.7777 - val_mean_absolute_error: 12.5560
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1043.9968 - mean_absolute_error: 27.4817 - val_loss: 202.1267 - val_mean_absolute_error: 12.4940
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 984.1267 - mean_absolute_error: 26.3322 - val_loss: 205.5714 - val_mean_absolute_error: 12.6230
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1005.9957 - mean_absolute_error: 26.6212 - val_loss: 220.9986 - val_mean_absolute_error: 13.1836
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1065.2371 - mean_absolute_error: 27.6366 - val_loss: 251.9170 - val_mean_absolute_error: 14.2345
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1037.1304 - mean_absolute_error: 27.5670 - val_loss: 284.6080 - val_mean_absolute_error: 15.2601
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 994.0444 - mean_absolute_error: 26.6461 - val_loss: 309.4408 - val_mean_absolute_error: 16.0149
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1027.2516 - mean_absolute_error: 27.2324 - val_loss: 302.0860 - val_mean_absolute_error: 15.7836
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1033.6998 - mean_absolute_error: 27.4262 - val_loss: 295.1187 - val_mean_absolute_error: 15.5742
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1001.2307 - mean_absolute_error: 26.2338 - val_loss: 281.6222 - val_mean_absolute_error: 15.1696
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1075.9458 - mean_absolute_error: 27.7879 - val_loss: 276.7161 - val_mean_absolute_error: 15.0195
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 965.5804 - mean_absolute_error: 26.1872 - val_loss: 277.9808 - val_mean_absolute_error: 15.0584
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1036.3529 - mean_absolute_error: 27.3974 - val_loss: 268.6658 - val_mean_absolute_error: 14.7697
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1002.1720 - mean_absolute_error: 26.7101 - val_loss: 255.4895 - val_mean_absolute_error: 14.3505
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1014.4122 - mean_absolute_error: 27.1494 - val_loss: 255.9958 - val_mean_absolute_error: 14.3669
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 999.7921 - mean_absolute_error: 26.4743 - val_loss: 263.1425 - val_mean_absolute_error: 14.5956
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1025.1991 - mean_absolute_error: 27.1181 - val_loss: 272.5674 - val_mean_absolute_error: 14.8922
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1028.5773 - mean_absolute_error: 27.2066 - val_loss: 331.4457 - val_mean_absolute_error: 16.6938
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1040.4529 - mean_absolute_error: 27.6950 - val_loss: 258.9743 - val_mean_absolute_error: 14.4678
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1020.9296 - mean_absolute_error: 27.0564 - val_loss: 303.3015 - val_mean_absolute_error: 15.8407
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 981.1096 - mean_absolute_error: 26.5497 - val_loss: 292.7926 - val_mean_absolute_error: 15.5159
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1050.5723 - mean_absolute_error: 27.6322 - val_loss: 292.8266 - val_mean_absolute_error: 15.5240
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 973.5198 - mean_absolute_error: 26.1456 - val_loss: 261.2042 - val_mean_absolute_error: 14.5542
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 941.0939 - mean_absolute_error: 25.5996 - val_loss: 403.9073 - val_mean_absolute_error: 18.7688
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 992.6946 - mean_absolute_error: 26.8546 - val_loss: 286.7793 - val_mean_absolute_error: 15.3731
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 899.6979 - mean_absolute_error: 25.3287 - val_loss: 455.2934 - val_mean_absolute_error: 20.1289
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 925.3913 - mean_absolute_error: 25.3054 - val_loss: 188.7766 - val_mean_absolute_error: 12.0552
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 926.8995 - mean_absolute_error: 25.6097 - val_loss: 324.9664 - val_mean_absolute_error: 16.6062
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 932.1786 - mean_absolute_error: 26.0075 - val_loss: 480.0542 - val_mean_absolute_error: 20.7942
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 888.2368 - mean_absolute_error: 25.2927 - val_loss: 169.8440 - val_mean_absolute_error: 11.3718
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 871.5887 - mean_absolute_error: 24.9063 - val_loss: 317.1878 - val_mean_absolute_error: 16.4889
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 776.7301 - mean_absolute_error: 23.6231 - val_loss: 296.0453 - val_mean_absolute_error: 15.9241
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 634.7928 - mean_absolute_error: 21.2746 - val_loss: 443.8680 - val_mean_absolute_error: 20.1080
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 666.7001 - mean_absolute_error: 21.6985 - val_loss: 276.7109 - val_mean_absolute_error: 15.4212
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 538.9948 - mean_absolute_error: 19.5585 - val_loss: 408.3875 - val_mean_absolute_error: 19.2743
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 484.3214 - mean_absolute_error: 18.0561 - val_loss: 318.4554 - val_mean_absolute_error: 16.8139
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 452.0289 - mean_absolute_error: 17.6670 - val_loss: 126.7620 - val_mean_absolute_error: 9.7752
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 367.1835 - mean_absolute_error: 15.6434 - val_loss: 122.8257 - val_mean_absolute_error: 9.6113
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 320.1211 - mean_absolute_error: 14.3365 - val_loss: 158.4424 - val_mean_absolute_error: 11.2180
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 251.1940 - mean_absolute_error: 12.0013 - val_loss: 53.9155 - val_mean_absolute_error: 5.8858
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 258.5405 - mean_absolute_error: 12.4969 - val_loss: 60.2237 - val_mean_absolute_error: 6.2884
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 202.7012 - mean_absolute_error: 11.0025 - val_loss: 70.5832 - val_mean_absolute_error: 6.9210
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 173.5888 - mean_absolute_error: 9.5576 - val_loss: 32.7189 - val_mean_absolute_error: 4.9427
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 136.2329 - mean_absolute_error: 9.0787 - val_loss: 35.5692 - val_mean_absolute_error: 5.0954
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 103.2492 - mean_absolute_error: 7.5075 - val_loss: 41.3970 - val_mean_absolute_error: 5.3479
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 81.3274 - mean_absolute_error: 6.6098 - val_loss: 30.8930 - val_mean_absolute_error: 4.8942
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 71.4717 - mean_absolute_error: 6.1550 - val_loss: 31.2124 - val_mean_absolute_error: 4.8377
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 59.7728 - mean_absolute_error: 5.7543 - val_loss: 41.5449 - val_mean_absolute_error: 5.3995
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 65.5672 - mean_absolute_error: 6.1632 - val_loss: 30.6393 - val_mean_absolute_error: 4.8326
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 63.5025 - mean_absolute_error: 6.2171 - val_loss: 34.9502 - val_mean_absolute_error: 4.9262
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 43.7095 - mean_absolute_error: 5.1631 - val_loss: 65.9111 - val_mean_absolute_error: 6.5451
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 50.2701 - mean_absolute_error: 5.7666 - val_loss: 47.8487 - val_mean_absolute_error: 5.5366
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 46.9912 - mean_absolute_error: 5.1765 - val_loss: 50.5866 - val_mean_absolute_error: 5.6967
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 42.5558 - mean_absolute_error: 5.1626 - val_loss: 50.0505 - val_mean_absolute_error: 5.6718
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 40.8756 - mean_absolute_error: 4.9564 - val_loss: 36.6061 - val_mean_absolute_error: 4.9832
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 35.8096 - mean_absolute_error: 4.6645 - val_loss: 39.0290 - val_mean_absolute_error: 5.1126
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 37.5653 - mean_absolute_error: 4.8115 - val_loss: 34.3627 - val_mean_absolute_error: 4.8858
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 38.6017 - mean_absolute_error: 4.7510 - val_loss: 40.0957 - val_mean_absolute_error: 5.1635
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 35.5915 - mean_absolute_error: 4.5957 - val_loss: 50.9819 - val_mean_absolute_error: 5.7575
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 30.5854 - mean_absolute_error: 4.3463 - val_loss: 40.1047 - val_mean_absolute_error: 5.1692
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 30.3236 - mean_absolute_error: 4.3023 - val_loss: 64.2816 - val_mean_absolute_error: 6.4461
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 35.2152 - mean_absolute_error: 4.8801 - val_loss: 32.1595 - val_mean_absolute_error: 4.7977
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 42.4743 - mean_absolute_error: 5.0473 - val_loss: 32.0540 - val_mean_absolute_error: 4.7595
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 37.6171 - mean_absolute_error: 5.0483 - val_loss: 51.7002 - val_mean_absolute_error: 5.8115
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 35.5885 - mean_absolute_error: 4.9379 - val_loss: 46.7212 - val_mean_absolute_error: 5.5678
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 27.4055 - mean_absolute_error: 4.1083 - val_loss: 61.6897 - val_mean_absolute_error: 6.3303
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 31.1540 - mean_absolute_error: 4.5658 - val_loss: 36.4776 - val_mean_absolute_error: 4.9569

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
